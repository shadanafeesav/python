# %%
print("Hello")
# Out:
# Hello

# %%
print(10+20)
# Out:
# 30

# %%
x=10
print(x)
# Out:
# 10

# %%
name="john"
print('name:'+name)
# Out:
# name:john

# %%
x=5
x=6
print(x)
# Out:
# 6

# %%
a=2
b=4
c=a+b
print(c)
# Out:
# 6

# %%
age=22
mark=70.5
name="anu"
passed=True
print(type(age))
print(type(mark))
print(type(name))
print(type(passed))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
name=input("Enter your Name:")
# Out:
# Enter your Name:shada

# %%
age=int(input("Enter your age"))
# Out:
# Enter your age20

# %%
Name=str(input("Enter your Name:"))
print(Name)
Age=int(input("Enter your Age:"))
print(Age)
Mark=float(input("Enter your Mark:"))
print(Mark)
# Out:
# Enter your Name:hamna
# hamna
# Enter your Age:22
# 22
# Enter your Mark:75.5
# 75.5

# %%
a=int(input("Enter a Number:"))
b=int(input("Enter a Number:"))
sum=a+b
print("Sum=",sum)
# Out:
# Enter a Number:25
# Enter a Number:25
# Sum= 50

# %%
a=float(input("Enter the Length of Square:"))
area=a*a
print("area=",area)
# Out:
# Enter the Length of Square:4
# area= 16.0

# %%
a=int(input("Enter 1st Number="))
b=int(input("Enter 2nd Number"))
c=a+b
d=a-b
e=a*b
print("add=",c)
print("sub=",d)
print("product=",e)
# Out:
# Enter 1st Number=3
# Enter 2nd Number2
# add= 5
# sub= 1
# product= 6

# %%
a=int(input("Enter the 1st Number="))
b=int(input("Enter the 2nd number"))
n=a//b
m=a%b
print("quotient=",n)
print("remainder=",m)
# Out:
# Enter the 1st Number=4
# Enter the 2nd number2
# quotient= 2
# remainder= 0

# %%
r=float(input("Enter the Radius="))
area=3.14*r*r
print("Area=",area)
# Out:
# Enter the Radius=5
# Area= 78.5

# %%
a=int(input("Enter a="))
b=int(input("Enter b="))
c=int(input("Enter c="))
avg=(a+b+c)/3
print("average=",avg)
# Out:
# Enter a=3
# Enter b=2
# Enter c=4
# average= 3.0

# %%
a=float(input("Enter a Celsius="))
fahrenheit=(c*9/5)+32
print("fahrenheit=",fahrenheit)
# Out:
# Enter a Celsius=25
# fahrenheit= 39.2

# %%
n=int(input("Enter a Number:"))
if n > 100:
     print("Number is Greater than 100")
# Out:
# Enter a Number:150
# Number is Greater than 100

# %%
n=int(input("Enter a Number:"))
if n > 100:
     print("Number is Greater than 100")
else:
     print("Not Greater")
# Out:
# Enter a Number:100
# Not Greater
